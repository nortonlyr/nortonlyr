# %%
import jieba
cut = jieba.cut('Python, R, AWS, Spark, SQL, NoSQL, Kafka, Unittest, maplotlib,seaborn, nltk, Airflow, Tableau, plotly, pandas, numpy, Java, BASH')
string = ''.join(cut)
print(string)
# Out:
# Python, R, AWS, Spark, SQL, NoSQL, Kafka, Unittest, maplotlib,seaborn, nltk, Airflow, Tableau, plotly, pandas, numpy, Java, BASH

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud

# %%
string = 'Python, R, AWS, Spark, SQL, NoSQL, Kafka, Unittest, \
maplotlib, nltk, Airflow, Tableau, plotly, pandas, numpy, Java, BASH,\
EC2, RDS, S3, ggplot'

wc = WordCloud(background_color = 'white', 
              width = 1000, 
              height = 800, 
              ).generate(string)
wc.to_file('skills.png')
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
import jieba
from matplotlib import pyplot as plt
from wordcloud import WordCloud
from PIL import Image
import numpy as np

# %%
# text = 'Python, R, AWS, Spark, SQL, NoSQL, Kafka, Unittest, \
# maplotlib, nltk, Airflow, Tableau, plotly, pandas, numpy, Java, BASH,\
# EC2, RDS, S3, ggplot'
# cut = jieba.cut(text)
# string = ''.join(cut)

string = 'Python, R, AWS, Spark, SQL, NoSQL, Kafka, Unittest, \
maplotlib, nltk, Airflow, Tableau, plotly, pandas, numpy, Java, BASH,\
EC2, RDS, S3, ggplot'
img = Image.open('DATA1.png')
img_array = np.array(img)
# stopword = []
wc = WordCloud(
    background_color = 'white',
    width = 1000,
    height = 800,
    mask = img_array)
#     font_path = font,
#     stopwords = stopwords

wc.generate(string)
plt.imshow(wc)
plt.axis('off')
plt.figure()
plt.show()
wc.to_file('new_data_world.png')

plt.imshow(img_array)
